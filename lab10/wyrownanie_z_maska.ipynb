# %%
from PIL import Image
from PIL import ImageOps
import matplotlib.pyplot as plt
from PIL import ImageFilter
from PIL import ImageStat as stat

# %%
def statystyki(im):
    s = stat.Stat(im)
    print("extrema ", s.extrema)  # max i min
    print("count ", s.count)  # zlicza
    print("mean ", s.mean)  # srednia
    print("median ", s.median)  # mediana
    print("stddev ", s.stddev)  # odchylenie standardowe

# %%
im0 = Image.open("brain.png")
print(im0.mode)
print(im0.size)
# Out:
# RGBA
# (352, 326)
# extrema  [(0, 255), (0, 255), (0, 255), (255, 255)]
# count  [114752, 114752, 114752, 114752]
# mean  [64.40476854433909, 64.40476854433909, 64.40476854433909, 255.0]
# median  [68, 68, 68, 255]
# stddev  [45.56588189784377, 45.56588189784377, 45.56588189784377, 0.0]

# %%
im = im0.crop((0, 2, im0.size[0], im0.size[1]))
r, g, b, a = im.split()

# %%
r
# Out:
# <PIL.Image.Image image mode=L size=352x324 at 0x2EFD40D3A90>

# %%
wsp = 11
cz_bia = r.point(lambda x: 255 if x > wsp else 0)
cz_bia
# Out:
# <PIL.Image.Image image mode=L size=352x324 at 0x2EFD36AD970>

# %%
for _ in range(2):
    cz_bia = cz_bia.filter(ImageFilter.MaxFilter(3))
cz_bia
# Out:
# <PIL.Image.Image image mode=L size=352x324 at 0x2EFD64E07F0>

# %%
for _ in range(2):
    cz_bia = cz_bia.filter(ImageFilter.MinFilter(3))
cz_bia
# Out:
# <PIL.Image.Image image mode=L size=352x324 at 0x2EFD64E02E0>

# %%
for _ in range(2):
    cz_bia = cz_bia.filter(ImageFilter.MaxFilter(3))
cz_bia
# Out:
# <PIL.Image.Image image mode=L size=352x324 at 0x2EFCB5949A0>

# %%
for _ in range(2):
    cz_bia = cz_bia.filter(ImageFilter.MinFilter(3))
cz_bia
# Out:
# <PIL.Image.Image image mode=L size=352x324 at 0x2EFD3C26250>

# %%
im_equalized1 = ImageOps.equalize(r, mask=cz_bia)
im_equalized1
# Out:
# <PIL.Image.Image image mode=L size=352x324 at 0x2EFD3FAD970>

# %%
hist = im_equalized1.histogram()
plt.title("histogram ")
plt.bar(range(256), hist[:], color='b', alpha=0.8)
# Out:
# <BarContainer object of 256 artists>
